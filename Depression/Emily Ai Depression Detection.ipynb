# %% [markdown]
# # Emily Ai Model Training
# Depression Detection Model

# %%
# All required imports
import numpy as np
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.utils import np_utils
from keras import backend as K
import tensorflow as tf
# from tensorflow.keras import regularizers
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Preprocessing the dataset

# %%
def preprocess(X_train, X_test):
    """
    Convert from float64 to float32 and normalize normalize to decibels
    relative to full scale (dBFS) for the 4 sec clip.
    """
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')

    X_train = np.array([(X - X.min()) / (X.max() - X.min()) for X in X_train])
    X_test = np.array([(X - X.min()) / (X.max() - X.min()) for X in X_test])
    return X_train, X_test

# %% [markdown]
# # Train Test divide and Image Resizing

# %%
def prep_train_test(X_train, y_train, X_test, y_test, nb_classes):
    """
    Prep samples ands labels for Keras input by noramalzing and converting
    labels to a categorical representation.
    """
    print('Train on {} samples, validate on {}'.format(X_train.shape[0],
                                                       X_test.shape[0]))

    # normalize to dBfS
    X_train, X_test = preprocess(X_train, X_test)

    # Convert class vectors to binary class matrices
    Y_train = np_utils.to_categorical(y_train, nb_classes)
    Y_test = np_utils.to_categorical(y_test, nb_classes)

    return X_train, X_test, Y_train, Y_test

def keras_img_prep(X_train, X_test, img_dep, img_rows, img_cols):
    """
    Reshape feature matrices for Keras' expexcted input dimensions.
    For 'th' (Theano) dim_order, the model expects dimensions:
    (# channels, # images, # rows, # cols).
    """
    X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
    X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
    return X_train, X_test, input_shape

# %% [markdown]
# # Model Defination

# %%
def cnn(X_train, y_train, X_test, y_test, batch_size,
        nb_classes, epochs, input_shape):
  weights = {
          0: np.random.rand(),
          1: np.random.rand()
        }
  path = r"/content/drive/MyDrive/Emily"
  checkpoint_filepath = path+'/weights-{epoch:02d}-acc{val_accuracy:.4f}-loss{val_loss:.4f}.h5'
  model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
  model = Sequential()
  # model.add(Conv2D(32, (5,5), activation='relu', input_shape=input_shape))
  # model.add(MaxPooling2D((4, 4), strides=4))
  # model.add(Conv2D(32, (3, 3), activation='relu'))
  # model.add(MaxPooling2D((1, 3), strides=(1,3)))
  # model.add(Flatten())
  # model.add(Dense(128, activation='linear'))
  # model.add(Dropout(0.6))
  # model.add(Dense(256, activation='relu'))
  # model.add(Dropout(0.8))
  # model.add(Dense(2, activation='sigmoid'))
  model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape, kernel_regularizer=tf.keras.regularizers.l2(0.1)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.1))
  model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.1)))
  model.add(MaxPooling2D((2, 2)))
  # model.add(Conv2D(128, (3, 3), activation='relu'))
  # model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(32, activation='relu'))
  model.add(Dense(2, activation='sigmoid'))
  model.compile(optimizer=tf.keras.optimizers.Adagrad(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

  history = model.fit(X_train,
                        y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=1, 
                        validation_data=(X_test, y_test),
                        shuffle=True,
                        callbacks=[model_checkpoint_callback],
                        # validation_split=0.1
                        class_weight={0:np.random.rand(),1:np.random.rand()}, 
                        )
  return model, history

# %% [markdown]
# # Main Runner Code

# %%
# Loading Dataset
path = r"/content/drive/MyDrive/Emily"

# Loading Dataset
X_train = np.load(
        path+'/train_samples.npz')
y_train = np.load(
        path+'/train_labels.npz')
X_test = np.load(
        path+'/test_samples.npz')
y_test = np.load(
        path+'/test_labels.npz')

X_train, y_train, X_test, y_test = \
        X_train['arr_0'], y_train['arr_0'], X_test['arr_0'], y_test['arr_0']

# %%
# Hyper Parameters
batch_size = 32
nb_classes = 2
epochs = 100
# Train Test Size Update
X_train, X_test, y_train, y_test = prep_train_test(X_train, y_train,
                                                       X_test, y_test,
                                                       nb_classes=nb_classes)

# 513x125x1 for spectrogram with crop size of 125 pixels
img_rows, img_cols, img_depth = X_train.shape[1], X_train.shape[2], 1

# Spectogram Image Processing
X_train, X_test, input_shape = keras_img_prep(X_train, X_test, img_depth,
                                                  img_rows, img_cols)

# print(y_test)
# print(y_train)

# Loaing and Fitting The model
model, history = cnn(X_train, y_train, X_test, y_test, batch_size,
                         nb_classes, epochs, input_shape)
# Out:
# Train on 2296 samples, validate on 820
# Epoch 1/100
# 72/72 [==============================] - 23s 138ms/step - loss: 4.5237 - accuracy: 0.5000 - val_loss: 4.9627 - val_accuracy: 0.5000
# Epoch 2/100
# 72/72 [==============================] - 8s 118ms/step - loss: 4.1659 - accuracy: 0.5000 - val_loss: 4.6771 - val_accuracy: 0.5000
# Epoch 3/100
# 72/72 [==============================] - 9s 119ms/step - loss: 3.8531 - accuracy: 0.5000 - val_loss: 4.3477 - val_accuracy: 0.5000
# Epoch 4/100
# 72/72 [==============================] - 9s 118ms/step - loss: 3.5767 - accuracy: 0.5000 - val_loss: 4.1712 - val_accuracy: 0.5000
# Epoch 5/100
# 72/72 [==============================] - 9s 119ms/step - loss: 3.3292 - accuracy: 0.5000 - val_loss: 3.8418 - val_accuracy: 0.5000
# Epoch 6/100
# 72/72 [==============================] - 9s 119ms/step - loss: 3.1062 - accuracy: 0.5000 - val_loss: 3.6493 - val_accuracy: 0.5000
# Epoch 7/100
# 72/72 [==============================] - 9s 119ms/step - loss: 2.9035 - accuracy: 0.5000 - val_loss: 3.4837 - val_accuracy: 0.5000
# Epoch 8/100
# 72/72 [==============================] - 9s 119ms/step - loss: 2.7198 - accuracy: 0.5000 - val_loss: 3.2998 - val_accuracy: 0.5000
# Epoch 9/100
# 72/72 [==============================] - 9s 125ms/step - loss: 2.5517 - accuracy: 0.5000 - val_loss: 3.1210 - val_accuracy: 0.5000
# Epoch 10/100
# 72/72 [==============================] - 9s 120ms/step - loss: 2.3977 - accuracy: 0.5000 - val_loss: 2.9943 - val_accuracy: 0.5000
# Epoch 11/100
# 72/72 [==============================] - 9s 120ms/step - loss: 2.2561 - accuracy: 0.5000 - val_loss: 2.8331 - val_accuracy: 0.5000
# Epoch 12/100
# 72/72 [==============================] - 9s 119ms/step - loss: 2.1258 - accuracy: 0.5000 - val_loss: 2.7088 - val_accuracy: 0.5000
# Epoch 13/100
# 72/72 [==============================] - 9s 119ms/step - loss: 2.0053 - accuracy: 0.5000 - val_loss: 2.6121 - val_accuracy: 0.5000
# Epoch 14/100
# 72/72 [==============================] - 9s 119ms/step - loss: 1.8939 - accuracy: 0.5000 - val_loss: 2.4917 - val_accuracy: 0.5000
# Epoch 15/100
# 72/72 [==============================] - 9s 120ms/step - loss: 1.7907 - accuracy: 0.5000 - val_loss: 2.3975 - val_accuracy: 0.5000
# Epoch 16/100
# 72/72 [==============================] - 9s 120ms/step - loss: 1.6950 - accuracy: 0.5000 - val_loss: 2.3129 - val_accuracy: 0.5000
# Epoch 17/100
# 72/72 [==============================] - 9s 119ms/step - loss: 1.6059 - accuracy: 0.5000 - val_loss: 2.1989 - val_accuracy: 0.5000
# Epoch 18/100
# 72/72 [==============================] - 9s 120ms/step - loss: 1.5232 - accuracy: 0.5000 - val_loss: 2.1418 - val_accuracy: 0.5000
# Epoch 19/100
# 72/72 [==============================] - 9s 127ms/step - loss: 1.4460 - accuracy: 0.5000 - val_loss: 2.0660 - val_accuracy: 0.5000
# Epoch 20/100
# 72/72 [==============================] - 9s 119ms/step - loss: 1.3741 - accuracy: 0.5000 - val_loss: 1.9973 - val_accuracy: 0.5000
# Epoch 21/100
# 72/72 [==============================] - 9s 125ms/step - loss: 1.3069 - accuracy: 0.5000 - val_loss: 1.9325 - val_accuracy: 0.5000
# Epoch 22/100
# 72/72 [==============================] - 9s 120ms/step - loss: 1.2440 - accuracy: 0.5000 - val_loss: 1.8897 - val_accuracy: 0.5000
# Epoch 23/100
# 72/72 [==============================] - 9s 120ms/step - loss: 1.1853 - accuracy: 0.5000 - val_loss: 1.8263 - val_accuracy: 0.5000
# Epoch 24/100
# 72/72 [==============================] - 9s 120ms/step - loss: 1.1304 - accuracy: 0.5000 - val_loss: 1.7675 - val_accuracy: 0.5000
# Epoch 25/100
# 72/72 [==============================] - 9s 120ms/step - loss: 1.0789 - accuracy: 0.5000 - val_loss: 1.7175 - val_accuracy: 0.5000
# Epoch 26/100
# 72/72 [==============================] - 9s 120ms/step - loss: 1.0307 - accuracy: 0.5000 - val_loss: 1.6694 - val_accuracy: 0.5000
# Epoch 27/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.9852 - accuracy: 0.5000 - val_loss: 1.6497 - val_accuracy: 0.5000
# Epoch 28/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.9429 - accuracy: 0.5000 - val_loss: 1.5864 - val_accuracy: 0.5000
# Epoch 29/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.9030 - accuracy: 0.5000 - val_loss: 1.5414 - val_accuracy: 0.5000
# Epoch 30/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.8654 - accuracy: 0.5000 - val_loss: 1.5041 - val_accuracy: 0.5000
# Epoch 31/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.8301 - accuracy: 0.5000 - val_loss: 1.4738 - val_accuracy: 0.5000
# Epoch 32/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.7970 - accuracy: 0.5000 - val_loss: 1.4390 - val_accuracy: 0.5000
# Epoch 33/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.7658 - accuracy: 0.5000 - val_loss: 1.4230 - val_accuracy: 0.5000
# Epoch 34/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.7364 - accuracy: 0.5000 - val_loss: 1.3879 - val_accuracy: 0.5000
# Epoch 35/100
# 72/72 [==============================] - 8s 118ms/step - loss: 0.7087 - accuracy: 0.5000 - val_loss: 1.3670 - val_accuracy: 0.5000
# Epoch 36/100
# 72/72 [==============================] - 9s 118ms/step - loss: 0.6826 - accuracy: 0.5000 - val_loss: 1.3344 - val_accuracy: 0.5000
# Epoch 37/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.6581 - accuracy: 0.5000 - val_loss: 1.3242 - val_accuracy: 0.5000
# Epoch 38/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.6349 - accuracy: 0.5000 - val_loss: 1.2982 - val_accuracy: 0.5000
# Epoch 39/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.6130 - accuracy: 0.5000 - val_loss: 1.2726 - val_accuracy: 0.5000
# Epoch 40/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.5923 - accuracy: 0.5000 - val_loss: 1.2624 - val_accuracy: 0.5000
# Epoch 41/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.5729 - accuracy: 0.5000 - val_loss: 1.2398 - val_accuracy: 0.5000
# Epoch 42/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.5544 - accuracy: 0.5000 - val_loss: 1.2274 - val_accuracy: 0.5000
# Epoch 43/100
# 72/72 [==============================] - 8s 118ms/step - loss: 0.5371 - accuracy: 0.5000 - val_loss: 1.2060 - val_accuracy: 0.5000
# Epoch 44/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.5207 - accuracy: 0.5000 - val_loss: 1.1852 - val_accuracy: 0.5000
# Epoch 45/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.5051 - accuracy: 0.5000 - val_loss: 1.1684 - val_accuracy: 0.5000
# Epoch 46/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.4904 - accuracy: 0.5000 - val_loss: 1.1583 - val_accuracy: 0.5000
# Epoch 47/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.4765 - accuracy: 0.5000 - val_loss: 1.1339 - val_accuracy: 0.5000
# Epoch 48/100
# 72/72 [==============================] - 9s 118ms/step - loss: 0.4635 - accuracy: 0.5000 - val_loss: 1.1318 - val_accuracy: 0.5000
# Epoch 49/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.4509 - accuracy: 0.5000 - val_loss: 1.1381 - val_accuracy: 0.5000
# Epoch 50/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.4393 - accuracy: 0.5000 - val_loss: 1.1149 - val_accuracy: 0.5000
# Epoch 51/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.4281 - accuracy: 0.5000 - val_loss: 1.0926 - val_accuracy: 0.5000
# Epoch 52/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.4176 - accuracy: 0.5000 - val_loss: 1.1006 - val_accuracy: 0.5000
# Epoch 53/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.4076 - accuracy: 0.5000 - val_loss: 1.0890 - val_accuracy: 0.5000
# Epoch 54/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3981 - accuracy: 0.5000 - val_loss: 1.0715 - val_accuracy: 0.5000
# Epoch 55/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3892 - accuracy: 0.5000 - val_loss: 1.0678 - val_accuracy: 0.5000
# Epoch 56/100
# 72/72 [==============================] - 9s 125ms/step - loss: 0.3806 - accuracy: 0.5000 - val_loss: 1.0543 - val_accuracy: 0.5000
# Epoch 57/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3726 - accuracy: 0.5000 - val_loss: 1.0565 - val_accuracy: 0.5000
# Epoch 58/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3650 - accuracy: 0.5000 - val_loss: 1.0526 - val_accuracy: 0.5000
# Epoch 59/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3577 - accuracy: 0.5000 - val_loss: 1.0487 - val_accuracy: 0.5000
# Epoch 60/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3508 - accuracy: 0.5000 - val_loss: 1.0343 - val_accuracy: 0.5000
# Epoch 61/100
# 72/72 [==============================] - 9s 120ms/step - loss: 0.3443 - accuracy: 0.5000 - val_loss: 1.0288 - val_accuracy: 0.5000
# Epoch 62/100
# 72/72 [==============================] - 9s 120ms/step - loss: 0.3381 - accuracy: 0.5000 - val_loss: 1.0227 - val_accuracy: 0.5000
# Epoch 63/100
# 72/72 [==============================] - 9s 120ms/step - loss: 0.3322 - accuracy: 0.5000 - val_loss: 1.0213 - val_accuracy: 0.5000
# Epoch 64/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3266 - accuracy: 0.5000 - val_loss: 1.0132 - val_accuracy: 0.5000
# Epoch 65/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3214 - accuracy: 0.5000 - val_loss: 1.0094 - val_accuracy: 0.5000
# Epoch 66/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.3163 - accuracy: 0.5000 - val_loss: 0.9943 - val_accuracy: 0.5000
# Epoch 67/100
# 72/72 [==============================] - 9s 118ms/step - loss: 0.3116 - accuracy: 0.5000 - val_loss: 1.0033 - val_accuracy: 0.5000
# Epoch 68/100
# 72/72 [==============================] - 9s 124ms/step - loss: 0.3070 - accuracy: 0.5000 - val_loss: 0.9944 - val_accuracy: 0.5000
# Epoch 69/100
# 72/72 [==============================] - 9s 126ms/step - loss: 0.3027 - accuracy: 0.5000 - val_loss: 0.9981 - val_accuracy: 0.5000
# Epoch 70/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2986 - accuracy: 0.5000 - val_loss: 0.9918 - val_accuracy: 0.5000
# Epoch 71/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2947 - accuracy: 0.5000 - val_loss: 0.9883 - val_accuracy: 0.5000
# Epoch 72/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2910 - accuracy: 0.5000 - val_loss: 0.9803 - val_accuracy: 0.5000
# Epoch 73/100
# 72/72 [==============================] - 9s 118ms/step - loss: 0.2874 - accuracy: 0.5000 - val_loss: 0.9795 - val_accuracy: 0.5000
# Epoch 74/100
# 72/72 [==============================] - 8s 118ms/step - loss: 0.2841 - accuracy: 0.5000 - val_loss: 0.9822 - val_accuracy: 0.5000
# Epoch 75/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2809 - accuracy: 0.5000 - val_loss: 0.9779 - val_accuracy: 0.5000
# Epoch 76/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2779 - accuracy: 0.5000 - val_loss: 0.9747 - val_accuracy: 0.5000
# Epoch 77/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2750 - accuracy: 0.5000 - val_loss: 0.9753 - val_accuracy: 0.5000
# Epoch 78/100
# 72/72 [==============================] - 9s 118ms/step - loss: 0.2722 - accuracy: 0.5000 - val_loss: 0.9683 - val_accuracy: 0.5000
# Epoch 79/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2697 - accuracy: 0.5000 - val_loss: 0.9692 - val_accuracy: 0.5000
# Epoch 80/100
# 72/72 [==============================] - 9s 118ms/step - loss: 0.2671 - accuracy: 0.5000 - val_loss: 0.9721 - val_accuracy: 0.5000
# Epoch 81/100
# 72/72 [==============================] - 9s 118ms/step - loss: 0.2648 - accuracy: 0.5000 - val_loss: 0.9713 - val_accuracy: 0.5000
# Epoch 82/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2625 - accuracy: 0.5000 - val_loss: 0.9622 - val_accuracy: 0.5000
# Epoch 83/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2604 - accuracy: 0.5000 - val_loss: 0.9577 - val_accuracy: 0.5000
# Epoch 84/100
# 72/72 [==============================] - 9s 125ms/step - loss: 0.2583 - accuracy: 0.5000 - val_loss: 0.9533 - val_accuracy: 0.5000
# Epoch 85/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2564 - accuracy: 0.5000 - val_loss: 0.9615 - val_accuracy: 0.5000
# Epoch 86/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2545 - accuracy: 0.5000 - val_loss: 0.9521 - val_accuracy: 0.5000
# Epoch 87/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2527 - accuracy: 0.5000 - val_loss: 0.9511 - val_accuracy: 0.5000
# Epoch 88/100
# 72/72 [==============================] - 9s 120ms/step - loss: 0.2510 - accuracy: 0.5000 - val_loss: 0.9582 - val_accuracy: 0.5000
# Epoch 89/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2494 - accuracy: 0.5000 - val_loss: 0.9551 - val_accuracy: 0.5000
# Epoch 90/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2479 - accuracy: 0.5000 - val_loss: 0.9542 - val_accuracy: 0.5000
# Epoch 91/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2464 - accuracy: 0.5000 - val_loss: 0.9455 - val_accuracy: 0.5000
# Epoch 92/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2450 - accuracy: 0.5000 - val_loss: 0.9455 - val_accuracy: 0.5000
# Epoch 93/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2436 - accuracy: 0.5000 - val_loss: 0.9493 - val_accuracy: 0.5000
# Epoch 94/100
# 72/72 [==============================] - 9s 120ms/step - loss: 0.2424 - accuracy: 0.5000 - val_loss: 0.9482 - val_accuracy: 0.5000
# Epoch 95/100
# 72/72 [==============================] - 9s 118ms/step - loss: 0.2411 - accuracy: 0.5000 - val_loss: 0.9479 - val_accuracy: 0.5000
# Epoch 96/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2400 - accuracy: 0.5000 - val_loss: 0.9470 - val_accuracy: 0.5000
# Epoch 97/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2389 - accuracy: 0.5000 - val_loss: 0.9461 - val_accuracy: 0.5000
# Epoch 98/100
# 72/72 [==============================] - 9s 119ms/step - loss: 0.2378 - accuracy: 0.5000 - val_loss: 0.9389 - val_accuracy: 0.5000
# Epoch 99/100
# 72/72 [==============================] - 9s 125ms/step - loss: 0.2368 - accuracy: 0.5000 - val_loss: 0.9404 - val_accuracy: 0.5000
# Epoch 100/100
# 72/72 [==============================] - 8s 118ms/step - loss: 0.2358 - accuracy: 0.5000 - val_loss: 0.9381 - val_accuracy: 0.5000

# %%
score_train = model.evaluate(X_train, y_train, verbose=1)
print('Train accuracy:', score_train[1])
score_test = model.evaluate(X_test, y_test, verbose=1)
print('Test accuracy:', score_test[1])
# Out:
# 72/72 [==============================] - 3s 36ms/step - loss: 0.9373 - accuracy: 0.5000
# Train accuracy: 0.5
# 26/26 [==============================] - 1s 35ms/step - loss: 0.9381 - accuracy: 0.5000
# Test accuracy: 0.5
